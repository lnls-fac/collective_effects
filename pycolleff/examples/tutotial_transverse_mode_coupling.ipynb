# %% [markdown]
# # Import packages

# %%
from functools import partial

import numpy as np
import matplotlib.pyplot as mplt

from pycolleff.longitudinal_equilibrium import ImpedanceSource, \
    LongitudinalEquilibrium
import pycolleff.rings.sirius as sirius
import pycolleff.impedances as imp
import pycolleff.materials_params as mat_par

# %% [markdown]
# # Create a resistive wall impedance to be used as example

# %%
cu_cond = mat_par.cu_cond
cu_rel_time = mat_par.cu_rel_time
neg_cond = mat_par.neg_cond
neg_rel_time = mat_par.neg_rel_time
neg_thick = mat_par.neg_thick
ndfe_cond = mat_par.ndfe_cond
ndfe_mur = mat_par.ndfe_mur

energy = 3e9  # [eV]
length = 500  # [m]

epb = np.array([1, 1, 1, 1, 1])
mub = np.array([1, 1, 1, 1, ndfe_mur])
ange = np.array([0, 0, 0, 0, 0])
angm = np.array([0, 0, 0, 0, 0])
sigmadc = np.array([0, neg_cond, cu_cond, 0, ndfe_cond])
tau = np.array([0, neg_rel_time, cu_rel_time, 0, 0])

radius = 12e-3 + np.array([-neg_thick, 0, 1e-3, 3e-3])

ang_freq = imp.get_default_reswall_w(radius=radius[0], energy=energy)

epr, mur = imp.prepare_inputs_epr_mur(
    ang_freq, epb, mub, ange, angm, sigmadc, tau
)

Zll, Zdx, Zdy = imp.multilayer_round_chamber(
    ang_freq,
    length,
    energy,
    epr,
    mur,
    radius,
    precision=70,
    wmax_arb_prec=1e12,
    arb_prec_incl_long=False,
    print_progress=True,
)

Zll, ang_freq = imp.get_impedance_for_negative_w(
    Zll, ang_freq, impedance_type='ll'
)
Zdx = imp.get_impedance_for_negative_w(Zdx, impedance_type='t')
Zdy = imp.get_impedance_for_negative_w(Zdy, impedance_type='t')

generic = ImpedanceSource()
generic.zl_table = Zll
generic.ang_freq_table = ang_freq

# Methods: Impedance or Wake
generic.calc_method = ImpedanceSource.Methods.ImpedanceDFT

# Device type: Active of Passive
generic.active_passive = ImpedanceSource.ActivePassive.Passive
# Out:
# 0000/0302 -> freq =        0.1  (ET: 0.11 s)
# 0001/0302 -> freq =       0.11  (ET: 0.03 s)
# 0002/0302 -> freq =       0.12  (ET: 0.03 s)
# 0003/0302 -> freq =       0.13  (ET: 0.03 s)
# 0004/0302 -> freq =       0.15  (ET: 0.03 s)
# 0005/0302 -> freq =       0.16  (ET: 0.03 s)
# 0006/0302 -> freq =       0.17  (ET: 0.03 s)
# 0007/0302 -> freq =       0.19  (ET: 0.03 s)
# 0008/0302 -> freq =       0.21  (ET: 0.03 s)
# 0009/0302 -> freq =       0.23  (ET: 0.05 s)
# 0010/0302 -> freq =       0.25  (ET: 0.05 s)
# 0011/0302 -> freq =       0.28  (ET: 0.03 s)
# 0012/0302 -> freq =       0.31  (ET: 0.03 s)
# 0013/0302 -> freq =       0.34  (ET: 0.03 s)
# 0014/0302 -> freq =       0.37  (ET: 0.03 s)
# 0015/0302 -> freq =        0.4  (ET: 0.03 s)
# 0016/0302 -> freq =       0.44  (ET: 0.03 s)
# 0017/0302 -> freq =       0.49  (ET: 0.03 s)
# 0018/0302 -> freq =       0.53  (ET: 0.04 s)
# 0019/0302 -> freq =       0.59  (ET: 0.06 s)
# 0020/0302 -> freq =       0.64  (ET: 0.05 s)
# 0021/0302 -> freq =       0.71  (ET: 0.06 s)
# 0022/0302 -> freq =       0.77  (ET: 0.06 s)
# 0023/0302 -> freq =       0.85  (ET: 0.05 s)
# 0024/0302 -> freq =       0.93  (ET: 0.04 s)
# 0025/0302 -> freq =          1  (ET: 0.03 s)
# 0026/0302 -> freq =        1.1  (ET: 0.03 s)
# 0027/0302 -> freq =        1.2  (ET: 0.03 s)
# 0028/0302 -> freq =        1.4  (ET: 0.04 s)
# 0029/0302 -> freq =        1.5  (ET: 0.03 s)
# 0030/0302 -> freq =        1.6  (ET: 0.04 s)
# 0031/0302 -> freq =        1.8  (ET: 0.04 s)
# 0032/0302 -> freq =          2  (ET: 0.04 s)
# 0033/0302 -> freq =        2.2  (ET: 0.03 s)
# 0034/0302 -> freq =        2.4  (ET: 0.03 s)
# 0035/0302 -> freq =        2.6  (ET: 0.03 s)
# 0036/0302 -> freq =        2.9  (ET: 0.03 s)
# 0037/0302 -> freq =        3.1  (ET: 0.03 s)
# 0038/0302 -> freq =        3.4  (ET: 0.03 s)
# 0039/0302 -> freq =        3.8  (ET: 0.04 s)
# 0040/0302 -> freq =        4.1  (ET: 0.03 s)
# 0041/0302 -> freq =        4.5  (ET: 0.04 s)
# 0042/0302 -> freq =          5  (ET: 0.03 s)
# 0043/0302 -> freq =        5.5  (ET: 0.03 s)
# 0044/0302 -> freq =          6  (ET: 0.03 s)
# 0045/0302 -> freq =        6.6  (ET: 0.06 s)
# 0046/0302 -> freq =        7.2  (ET: 0.05 s)
# 0047/0302 -> freq =        7.9  (ET: 0.05 s)
# 0048/0302 -> freq =        8.7  (ET: 0.05 s)
# 0049/0302 -> freq =        9.6  (ET: 0.06 s)
# 0050/0302 -> freq =         10  (ET: 0.05 s)
# 0051/0302 -> freq =         12  (ET: 0.05 s)
# 0052/0302 -> freq =         13  (ET: 0.05 s)
# 0053/0302 -> freq =         14  (ET: 0.05 s)
# 0054/0302 -> freq =         15  (ET: 0.05 s)
# 0055/0302 -> freq =         17  (ET: 0.05 s)
# 0056/0302 -> freq =         18  (ET: 0.05 s)
# 0057/0302 -> freq =         20  (ET: 0.05 s)
# 0058/0302 -> freq =         22  (ET: 0.05 s)
# 0059/0302 -> freq =         24  (ET: 0.05 s)
# 0060/0302 -> freq =         27  (ET: 0.05 s)
# 0061/0302 -> freq =         29  (ET: 0.05 s)
# 0062/0302 -> freq =         32  (ET: 0.05 s)
# 0063/0302 -> freq =         35  (ET: 0.05 s)
# 0064/0302 -> freq =         39  (ET: 0.05 s)
# 0065/0302 -> freq =         42  (ET: 0.05 s)
# 0066/0302 -> freq =         46  (ET: 0.05 s)
# 0067/0302 -> freq =         51  (ET: 0.05 s)
# 0068/0302 -> freq =         56  (ET: 0.05 s)
# 0069/0302 -> freq =         61  (ET: 0.05 s)
# 0070/0302 -> freq =         67  (ET: 0.05 s)
# 0071/0302 -> freq =         74  (ET: 0.06 s)
# 0072/0302 -> freq =         81  (ET: 0.06 s)
# 0073/0302 -> freq =         89  (ET: 0.06 s)
# 0074/0302 -> freq =         98  (ET: 0.06 s)
# 0075/0302 -> freq =    1.1e+02  (ET: 0.08 s)
# 0076/0302 -> freq =    1.2e+02  (ET: 0.06 s)
# 0077/0302 -> freq =    1.3e+02  (ET: 0.06 s)
# 0078/0302 -> freq =    1.4e+02  (ET: 0.06 s)
# 0079/0302 -> freq =    1.6e+02  (ET: 0.06 s)
# 0080/0302 -> freq =    1.7e+02  (ET: 0.06 s)
# 0081/0302 -> freq =    1.9e+02  (ET: 0.06 s)
# 0082/0302 -> freq =    2.1e+02  (ET: 0.06 s)
# 0083/0302 -> freq =    2.3e+02  (ET: 0.06 s)
# 0084/0302 -> freq =    2.5e+02  (ET: 0.06 s)
# 0085/0302 -> freq =    2.7e+02  (ET: 0.06 s)
# 0086/0302 -> freq =      3e+02  (ET: 0.06 s)
# 0087/0302 -> freq =    3.3e+02  (ET: 0.06 s)
# 0088/0302 -> freq =    3.6e+02  (ET: 0.06 s)
# 0089/0302 -> freq =      4e+02  (ET: 0.06 s)
# 0090/0302 -> freq =    4.3e+02  (ET: 0.06 s)
# 0091/0302 -> freq =    4.8e+02  (ET: 0.08 s)
# 0092/0302 -> freq =    5.2e+02  (ET: 0.08 s)
# 0093/0302 -> freq =    5.7e+02  (ET: 0.08 s)
# 0094/0302 -> freq =    6.3e+02  (ET: 0.08 s)
# 0095/0302 -> freq =    6.9e+02  (ET: 0.08 s)
# 0096/0302 -> freq =    7.6e+02  (ET: 0.08 s)
# 0097/0302 -> freq =    8.3e+02  (ET: 0.08 s)
# 0098/0302 -> freq =    9.1e+02  (ET: 0.08 s)
# 0099/0302 -> freq =      1e+03  (ET: 0.09 s)
# 0100/0302 -> freq =    1.1e+03  (ET: 0.08 s)
# 0101/0302 -> freq =    1.2e+03  (ET: 0.08 s)
# 0102/0302 -> freq =    1.3e+03  (ET: 0.09 s)
# 0103/0302 -> freq =    1.5e+03  (ET: 0.08 s)
# 0104/0302 -> freq =    1.6e+03  (ET: 0.09 s)
# 0105/0302 -> freq =    1.8e+03  (ET: 0.09 s)
# 0106/0302 -> freq =    1.9e+03  (ET: 0.09 s)
# 0107/0302 -> freq =    2.1e+03  (ET: 0.09 s)
# 0108/0302 -> freq =    2.3e+03  (ET: 0.09 s)
# 0109/0302 -> freq =    2.5e+03  (ET: 0.09 s)
# 0110/0302 -> freq =    2.8e+03  (ET: 0.09 s)
# 0111/0302 -> freq =    3.1e+03  (ET: 0.21 s)
# 0112/0302 -> freq =    3.4e+03  (ET: 0.12 s)
# 0113/0302 -> freq =    3.7e+03  (ET: 0.15 s)
# 0114/0302 -> freq =      4e+03  (ET: 0.17 s)
# 0115/0302 -> freq =    4.4e+03  (ET: 0.17 s)
# 0116/0302 -> freq =    4.9e+03  (ET: 0.17 s)
# 0117/0302 -> freq =    5.4e+03  (ET: 0.18 s)
# 0118/0302 -> freq =    5.9e+03  (ET: 0.18 s)
# 0119/0302 -> freq =    6.4e+03  (ET: 0.19 s)
# 0120/0302 -> freq =    7.1e+03  (ET: 0.37 s)
# 0121/0302 -> freq =    7.8e+03  (ET: 0.60 s)
# 0122/0302 -> freq =    8.5e+03  (ET: 0.60 s)
# 0123/0302 -> freq =    9.4e+03  (ET: 0.60 s)
# 0124/0302 -> freq =      1e+04  (ET: 0.61 s)
# 0125/0302 -> freq =    1.1e+04  (ET: 0.62 s)
# 0126/0302 -> freq =    1.2e+04  (ET: 0.61 s)
# 0127/0302 -> freq =    1.4e+04  (ET: 0.59 s)
# 0128/0302 -> freq =    1.5e+04  (ET: 0.58 s)
# 0129/0302 -> freq =    1.6e+04  (ET: 0.58 s)
# 0130/0302 -> freq =    1.8e+04  (ET: 0.58 s)
# 0131/0302 -> freq =      2e+04  (ET: 0.58 s)
# 0132/0302 -> freq =    2.2e+04  (ET: 0.58 s)
# 0133/0302 -> freq =    2.4e+04  (ET: 0.58 s)
# 0134/0302 -> freq =    2.6e+04  (ET: 0.58 s)
# 0135/0302 -> freq =    2.9e+04  (ET: 0.58 s)
# 0136/0302 -> freq =    3.1e+04  (ET: 0.58 s)
# 0137/0302 -> freq =    3.4e+04  (ET: 0.58 s)
# 0138/0302 -> freq =    3.8e+04  (ET: 0.58 s)
# 0139/0302 -> freq =    4.1e+04  (ET: 0.58 s)
# 0140/0302 -> freq =    4.6e+04  (ET: 0.58 s)
# 0141/0302 -> freq =      5e+04  (ET: 0.58 s)
# 0142/0302 -> freq =    5.5e+04  (ET: 0.58 s)
# 0143/0302 -> freq =      6e+04  (ET: 0.58 s)
# 0144/0302 -> freq =    6.6e+04  (ET: 0.59 s)
# 0145/0302 -> freq =    7.2e+04  (ET: 0.61 s)
# 0146/0302 -> freq =      8e+04  (ET: 0.61 s)
# 0147/0302 -> freq =    8.7e+04  (ET: 0.61 s)
# 0148/0302 -> freq =    9.6e+04  (ET: 0.63 s)
# 0149/0302 -> freq =    1.1e+05  (ET: 0.60 s)
# 0150/0302 -> freq =    1.2e+05  (ET: 0.61 s)
# 0151/0302 -> freq =    1.3e+05  (ET: 0.36 s)
# 0152/0302 -> freq =    1.4e+05  (ET: 0.20 s)
# 0153/0302 -> freq =    1.5e+05  (ET: 0.06 s)
# 0154/0302 -> freq =    1.7e+05  (ET: 0.06 s)
# 0155/0302 -> freq =    1.8e+05  (ET: 0.06 s)
# 0156/0302 -> freq =      2e+05  (ET: 0.06 s)
# 0157/0302 -> freq =    2.2e+05  (ET: 0.08 s)
# 0158/0302 -> freq =    2.4e+05  (ET: 0.11 s)
# 0159/0302 -> freq =    2.7e+05  (ET: 0.11 s)
# 0160/0302 -> freq =    2.9e+05  (ET: 0.11 s)
# 0161/0302 -> freq =    3.2e+05  (ET: 0.12 s)
# 0162/0302 -> freq =    3.5e+05  (ET: 0.12 s)
# 0163/0302 -> freq =    3.9e+05  (ET: 0.12 s)
# 0164/0302 -> freq =    4.2e+05  (ET: 0.12 s)
# 0165/0302 -> freq =    4.7e+05  (ET: 0.43 s)
# 0166/0302 -> freq =    5.1e+05  (ET: 0.47 s)
# 0167/0302 -> freq =    5.6e+05  (ET: 0.44 s)
# 0168/0302 -> freq =    6.2e+05  (ET: 0.45 s)
# 0169/0302 -> freq =    6.8e+05  (ET: 0.42 s)
# 0170/0302 -> freq =    7.4e+05  (ET: 0.42 s)
# 0171/0302 -> freq =    8.1e+05  (ET: 0.45 s)
# 0172/0302 -> freq =    8.9e+05  (ET: 0.50 s)
# 0173/0302 -> freq =    9.8e+05  (ET: 0.50 s)
# 0174/0302 -> freq =    1.1e+06  (ET: 0.46 s)
# 0175/0302 -> freq =    1.2e+06  (ET: 0.45 s)
# 0176/0302 -> freq =    1.3e+06  (ET: 0.43 s)
# 0177/0302 -> freq =    1.4e+06  (ET: 0.49 s)
# 0178/0302 -> freq =    1.6e+06  (ET: 0.45 s)
# 0179/0302 -> freq =    1.7e+06  (ET: 0.43 s)
# 0180/0302 -> freq =    1.9e+06  (ET: 0.41 s)
# 0181/0302 -> freq =    2.1e+06  (ET: 0.44 s)
# 0182/0302 -> freq =    2.3e+06  (ET: 0.41 s)
# 0183/0302 -> freq =    2.5e+06  (ET: 0.41 s)
# 0184/0302 -> freq =    2.7e+06  (ET: 0.41 s)
# 0185/0302 -> freq =      3e+06  (ET: 0.41 s)
# 0186/0302 -> freq =    3.3e+06  (ET: 0.41 s)
# 0187/0302 -> freq =    3.6e+06  (ET: 0.41 s)
# 0188/0302 -> freq =      4e+06  (ET: 0.41 s)
# 0189/0302 -> freq =    4.4e+06  (ET: 0.41 s)
# 0190/0302 -> freq =    4.8e+06  (ET: 0.41 s)
# 0191/0302 -> freq =    5.2e+06  (ET: 0.41 s)
# 0192/0302 -> freq =    5.8e+06  (ET: 0.41 s)
# 0193/0302 -> freq =    6.3e+06  (ET: 0.41 s)
# 0194/0302 -> freq =    6.9e+06  (ET: 0.42 s)
# 0195/0302 -> freq =    7.6e+06  (ET: 0.42 s)
# 0196/0302 -> freq =    8.3e+06  (ET: 0.42 s)
# 0197/0302 -> freq =    9.2e+06  (ET: 0.02 s)
# 0198/0302 -> freq =      1e+07  (ET: 0.02 s)
# 0199/0302 -> freq =    1.1e+07  (ET: 0.02 s)
# 0200/0302 -> freq =    1.2e+07  (ET: 0.02 s)
# 0201/0302 -> freq =    1.3e+07  (ET: 0.02 s)
# 0202/0302 -> freq =    1.5e+07  (ET: 0.02 s)
# 0203/0302 -> freq =    1.6e+07  (ET: 0.02 s)
# 0204/0302 -> freq =    1.8e+07  (ET: 0.02 s)
# 0205/0302 -> freq =    1.9e+07  (ET: 0.02 s)
# 0206/0302 -> freq =    2.1e+07  (ET: 0.02 s)
# 0207/0302 -> freq =    2.3e+07  (ET: 0.02 s)
# 0208/0302 -> freq =    2.5e+07  (ET: 0.02 s)
# 0209/0302 -> freq =    2.8e+07  (ET: 0.02 s)
# 0210/0302 -> freq =    3.1e+07  (ET: 0.02 s)
# 0211/0302 -> freq =    3.4e+07  (ET: 0.02 s)
# 0212/0302 -> freq =    3.7e+07  (ET: 0.02 s)
# 0213/0302 -> freq =    4.1e+07  (ET: 0.02 s)
# 0214/0302 -> freq =    4.5e+07  (ET: 0.02 s)
# 0215/0302 -> freq =    4.9e+07  (ET: 0.02 s)
# 0216/0302 -> freq =    5.4e+07  (ET: 0.02 s)
# 0217/0302 -> freq =    5.9e+07  (ET: 0.02 s)
# 0218/0302 -> freq =    6.5e+07  (ET: 0.02 s)
# 0219/0302 -> freq =    7.1e+07  (ET: 0.02 s)
# 0220/0302 -> freq =    7.8e+07  (ET: 0.02 s)
# 0221/0302 -> freq =    8.5e+07  (ET: 0.02 s)
# 0222/0302 -> freq =    9.4e+07  (ET: 0.02 s)
# 0223/0302 -> freq =      1e+08  (ET: 0.02 s)
# 0224/0302 -> freq =    1.1e+08  (ET: 0.02 s)
# 0225/0302 -> freq =    1.2e+08  (ET: 0.02 s)
# 0226/0302 -> freq =    1.4e+08  (ET: 0.02 s)
# 0227/0302 -> freq =    1.5e+08  (ET: 0.02 s)
# 0228/0302 -> freq =    1.6e+08  (ET: 0.02 s)
# 0229/0302 -> freq =    1.8e+08  (ET: 0.02 s)
# 0230/0302 -> freq =      2e+08  (ET: 0.02 s)
# 0231/0302 -> freq =    2.2e+08  (ET: 0.02 s)
# 0232/0302 -> freq =    2.4e+08  (ET: 0.02 s)
# 0233/0302 -> freq =    2.6e+08  (ET: 0.02 s)
# 0234/0302 -> freq =    2.9e+08  (ET: 0.02 s)
# 0235/0302 -> freq =    3.1e+08  (ET: 0.02 s)
# 0236/0302 -> freq =    3.5e+08  (ET: 0.02 s)
# 0237/0302 -> freq =    3.8e+08  (ET: 0.02 s)
# 0238/0302 -> freq =    4.2e+08  (ET: 0.02 s)
# 0239/0302 -> freq =    4.6e+08  (ET: 0.02 s)
# 0240/0302 -> freq =      5e+08  (ET: 0.02 s)
# 0241/0302 -> freq =    5.5e+08  (ET: 0.02 s)
# 0242/0302 -> freq =      6e+08  (ET: 0.02 s)
# 0243/0302 -> freq =    6.6e+08  (ET: 0.02 s)
# 0244/0302 -> freq =    7.3e+08  (ET: 0.02 s)
# 0245/0302 -> freq =      8e+08  (ET: 0.02 s)
# 0246/0302 -> freq =    8.8e+08  (ET: 0.02 s)
# 0247/0302 -> freq =    9.6e+08  (ET: 0.02 s)
# 0248/0302 -> freq =    1.1e+09  (ET: 0.02 s)
# 0249/0302 -> freq =    1.2e+09  (ET: 0.02 s)
# 0250/0302 -> freq =    1.3e+09  (ET: 0.02 s)
# 0251/0302 -> freq =    1.4e+09  (ET: 0.02 s)
# 0252/0302 -> freq =    1.5e+09  (ET: 0.02 s)
# 0253/0302 -> freq =    1.7e+09  (ET: 0.02 s)
# 0254/0302 -> freq =    1.8e+09  (ET: 0.02 s)
# 0255/0302 -> freq =      2e+09  (ET: 0.02 s)
# 0256/0302 -> freq =    2.2e+09  (ET: 0.02 s)
# 0257/0302 -> freq =    2.4e+09  (ET: 0.02 s)
# 0258/0302 -> freq =    2.7e+09  (ET: 0.02 s)
# 0259/0302 -> freq =    2.9e+09  (ET: 0.02 s)
# 0260/0302 -> freq =    3.2e+09  (ET: 0.02 s)
# 0261/0302 -> freq =    3.5e+09  (ET: 0.02 s)
# 0262/0302 -> freq =    3.9e+09  (ET: 0.02 s)
# 0263/0302 -> freq =    4.3e+09  (ET: 0.02 s)
# 0264/0302 -> freq =    4.7e+09  (ET: 0.02 s)
# 0265/0302 -> freq =    5.1e+09  (ET: 0.02 s)
# 0266/0302 -> freq =    5.6e+09  (ET: 0.02 s)
# 0267/0302 -> freq =    6.2e+09  (ET: 0.02 s)
# 0268/0302 -> freq =    6.8e+09  (ET: 0.02 s)
# 0269/0302 -> freq =    7.4e+09  (ET: 0.02 s)
# 0270/0302 -> freq =    8.2e+09  (ET: 0.02 s)
# 0271/0302 -> freq =      9e+09  (ET: 0.02 s)
# 0272/0302 -> freq =    9.8e+09  (ET: 0.02 s)
# 0273/0302 -> freq =    1.1e+10  (ET: 0.02 s)
# 0274/0302 -> freq =    1.2e+10  (ET: 0.02 s)
# 0275/0302 -> freq =    1.3e+10  (ET: 0.02 s)
# 0276/0302 -> freq =    1.4e+10  (ET: 0.02 s)
# 0277/0302 -> freq =    1.6e+10  (ET: 0.02 s)
# 0278/0302 -> freq =    1.7e+10  (ET: 0.02 s)
# 0279/0302 -> freq =    1.9e+10  (ET: 0.02 s)
# 0280/0302 -> freq =    2.1e+10  (ET: 0.02 s)
# 0281/0302 -> freq =    2.3e+10  (ET: 0.02 s)
# 0282/0302 -> freq =    2.5e+10  (ET: 0.02 s)
# 0283/0302 -> freq =    2.7e+10  (ET: 0.02 s)
# 0284/0302 -> freq =      3e+10  (ET: 0.02 s)
# 0285/0302 -> freq =    3.3e+10  (ET: 0.02 s)
# 0286/0302 -> freq =    3.6e+10  (ET: 0.02 s)
# 0287/0302 -> freq =      4e+10  (ET: 0.02 s)
# 0288/0302 -> freq =    4.4e+10  (ET: 0.02 s)
# 0289/0302 -> freq =    4.8e+10  (ET: 0.02 s)
# 0290/0302 -> freq =    5.3e+10  (ET: 0.02 s)
# 0291/0302 -> freq =    5.8e+10  (ET: 0.02 s)
# 0292/0302 -> freq =    6.3e+10  (ET: 0.02 s)
# 0293/0302 -> freq =    6.9e+10  (ET: 0.02 s)
# 0294/0302 -> freq =    7.6e+10  (ET: 0.02 s)
# 0295/0302 -> freq =    8.4e+10  (ET: 0.02 s)
# 0296/0302 -> freq =    9.2e+10  (ET: 0.02 s)
# 0297/0302 -> freq =      1e+11  (ET: 0.02 s)
# 0298/0302 -> freq =    1.1e+11  (ET: 0.02 s)
# 0299/0302 -> freq =    1.2e+11  (ET: 0.02 s)
# 0300/0302 -> freq =    1.3e+11  (ET: 0.02 s)
# 0301/0302 -> freq =    1.5e+11  (ET: 0.02 s)

# %% [markdown]
# # Define methods

# %%
def calculate_longeq_single_bunch_vs_current(
    ring, impedance_sources, currents
):
    """Calculate longitudinal equilibrium."""
    print('Calculating Longitudinal Equilibrium...')
    fillp = np.zeros(ring.harm_num, dtype=float)
    fillp[0] = 1
    longeq = LongitudinalEquilibrium(
        ring=ring,
        impedance_sources=impedance_sources,
        fillpattern=fillp * 1e-4,
    )
    longeq.feedback_on = False
    longeq.zgrid = np.linspace(-1, 1, 2001) * ring.rf_lamb / 2
    longeq.max_mode = 1000*ring.harm_num
    longeq.min_mode0_ratio = 1e-10  # criteria for convergence

    bunlen, syncfreq = [], []
    for current in currents:
        longeq.fillpattern = fillp * current
        _ = longeq.calc_longitudinal_equilibrium(
            niter=1000, tol=1e-8, beta=0.1, m=3, print_flag=True)
        hcav = longeq.impedance_sources[0]
        hvolt = longeq.calc_induced_voltage_wake(
            dist=longeq.distributions, wake_source=hcav)
        mvolt = longeq.main_voltage
        tvolt = mvolt + hvolt
        syncfreq.append(longeq.calc_synchrotron_frequency(
            tvolt, method="action", max_amp=5, nrpts=100
        )['avg_sync_freq'])
        dist, _ = longeq.calc_distributions_from_voltage(voltage=tvolt)
        _, sigmaz = longeq.calc_moments(longeq.zgrid, dist[0])
        bunlen.append(sigmaz[0])
    return bunlen, syncfreq


def calc_mode_coupling(
    ring,
    ang_freq,
    impedance,
    currents,
    plane='x',
    max_azi=4,
    max_rad=20,
    cbmode=0,
    use_fokker=True,
    bunlen_vs_current=None,
):
    """."""
    bunlen0 = ring.bunlen
    curr0 = ring.total_current

    dtunes = []
    mod_mat = fok_mat = None
    for i, cur in enumerate(currents):
        ring.total_current = cur
        if bunlen_vs_current is not None:
            ring.bunlen = np.interp(
                cur, bunlen_vs_current[0], bunlen_vs_current[1])
            mod_mat = None
        dtune, mod_mat, fok_mat = ring.transverse_mode_coupling(
            w=ang_freq,
            Zt=impedance,
            plane=plane,
            max_azi=max_azi,
            max_rad=max_rad,
            cbmode=cbmode,
            use_fokker=use_fokker,
            modecoup_matrix=mod_mat,
            fokker_matrix=fok_mat,
        )
        dtunes.append(dtune)
        print(
            f'{i+1:02d}/{len(currents):02d}: ' +
            f'Ib = {cur/ring.num_bun*1e3:7.3f} mA,   Grow Rate = ' +
            f'{dtune.imag.max()*ring.sync_tune*ring.rev_ang_freq:7.0f} 1/s'
        )

    ring.bunlen = bunlen0
    ring.total_current = curr0

    dtunes = np.array(dtunes)
    dtunes *= ring.sync_tune
    gr = dtunes.imag * ring.rev_ang_freq
    gr = np.sort(gr)
    tushif = np.sort(dtunes.real, axis=1)

    return gr, tushif
# Out:
#   Cell In[7], line 10
#     )
#     ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# # Define the ring model

# %%
ring = sirius.create_ring()
ring.en_lost_rad = 870e3
ring.gap_voltage = 3.0e6
ring.total_current = 350e-3
ring.chromx = 2.5
ring.chromy = 2.5
print(ring)
# Out:
# Lattice Version             :   SI.v25.01-s05.02
# Circumference [m]           :       518.387
# Revolution Period [us]      :        1.729
# Revolution Frequency [kHz]  :       578.318
# Energy [GeV]                :        3.000
# U0 [keV]                    :       870.000
# Vgap [MV]                   :        3.000
# Momentum Compaction         :       1.63e-04
# Harmonic Number             :         864
# Current [mA]                :       350.000
# Current per Bunch [mA]      :        0.405
# Synchrotron Tune            :       0.00356
# Tunes x/y                   :    49.078/14.137
# Chromaticities x/y          :     2.500/2.500
# Damping Times x/y/e [ms]    :   16.9/ 22.0 /12.9
# Energy Spread [%]           :        0.0887
# Bunch Length [mm]           :        3.250

# %% [markdown]
# # Calculate longitudinal equlibrium
#
# This step is important to model de dependency of bunch length and synchrotron frequency as function of the current.

# %%
currents = np.linspace(0, 20) * 1e-3
bunlen, syncfreq = calculate_longeq_single_bunch_vs_current(
    ring, [generic, ], currents
)
# Out:
# Calculating Longitudinal Equilibrium...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 currents = np.linspace(0, 20) * 1e-3
# ----> 2 bunlen, syncfreq = calculate_longeq_single_bunch_vs_current(
#       3     ring, [generic, ], currents
#       4 )
#
# Cell In[3], line 6, in calculate_longeq_single_bunch_vs_current(ring, impedance_sources, currents)
#       4 """Calculate longitudinal equilibrium."""
#       5 print('Calculating Longitudinal Equilibrium...')
# ----> 6 longeq = LongitudinalEquilibrium(
#       7     ring=ring, impedance_sources=impedance_sources,
#       8 )
#       9 longeq.feedback_on = False
#      10 longeq.zgrid = np.linspace(-1, 1, 2001) * ring.rf_lamb / 2
#
# File /home/facs/repos/collective_effects/pycolleff/pycolleff/longitudinal_equilibrium.py:309, in LongitudinalEquilibrium.__init__(self, ring, impedance_sources, fillpattern)
#     307 self.ring = ring
#     308 self.impedance_sources = impedance_sources
# --> 309 self.fillpattern = fillpattern
#     310 self._max_mode = 10 * self.ring.harm_num
#     311 self.min_mode0_ratio = 1e-9
#
# File /home/facs/repos/collective_effects/pycolleff/pycolleff/longitudinal_equilibrium.py:388, in LongitudinalEquilibrium.fillpattern(self, value)
#     386 @fillpattern.setter
#     387 def fillpattern(self, value):
# --> 388     if value.size != self.ring.harm_num:
#     389         raise ValueError("Wrong size for fillparttern.")
#     390     self._fillpattern = value
#
# AttributeError: 'NoneType' object has no attribute 'size'

# %% [markdown]
# # Calculate transverse mode-coupling

# %%
grow, freqshit = calc_mode_coupling(
    ring,
    ang_freq=ang_freq,
    impedance=Zdx,
    currents=currents,
    plane='x',
    max_azi=4,
    max_rad=20,
    use_fokker=True,
    bunlen_vs_current=(currents, bunlen),
)
